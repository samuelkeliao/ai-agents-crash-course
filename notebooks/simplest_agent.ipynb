# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant giving out nutrition advice.
    You give concise answers.
    """
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Bananas are quite healthy: they’re rich in potassium, vitamin C, vitamin B6, fiber, and manganese, with little fat or protein.
#
#     Pros:
#     - Supports heart health and digestion
#     - Provides quick energy from natural sugars
#     - Good for nerve function and electrolyte balance
#
#     Considerations:
#     - Moderate sugar content; portion size matters for diabetes or blood sugar goals (1 medium banana is common).
#     - Ripeness changes sugar/antioxidants (ripe = sweeter, more antioxidants; greener = starch).
#
#     Bottom line: a convenient, nutrient-dense snack or part of meals when eaten in typical portions. 1–2 medium bananas per day fits a balanced diet for most people.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Overall, yes—bananas are a healthy, convenient snack.
#
# Key positives:
# - Rich in potassium, vitamin B6, vitamin C, and fiber
# - Quick, natural energy from carbohydrates
# - Low in fat and cholesterol-free
#
# Things to consider:
# - Higher sugar content as they ripen (ripe = sweeter)
# - Some people with kidney disease or on certain meds may need to limit potassium
# - Can cause gas for some people due to fiber/fructose
#
# Bottom line: good for most people in moderation; pair with protein or fat for better satiety.

# %% [markdown]
# _Good Job!_
